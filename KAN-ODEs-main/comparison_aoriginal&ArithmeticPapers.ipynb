# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import scipy
from torchdiffeq import odeint as torchodeint
from tqdm import tqdm
import os
import gc
import torch.nn as nn
import sys
sys.path.append("Lotka-Volterra-Pytorch/efficient_kan/")
import efficientkan #from efficient kan

from torchdiffeq import odeint

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# loading parameters

# %%
# tf=14
# tf_learn=3.5
# N_t_train=35
# N_t=int((35*tf/tf_learn))
# lr=2e-3
# num_epochs=10000
# plot_freq=100
# is_restart=False


##coefficients from https://arxiv.org/pdf/2012.07244
alpha=1.5
beta=1
gamma=3
delta=1


x0=1.0
y0=1.0

# %%
def pred_prey_deriv(X, t, alpha, beta, delta, gamma):
    x=X[0]
    y=X[1]
    dxdt = alpha*x-beta*x*y
    dydt = delta*x*y-gamma*y
    dXdt=[dxdt, dydt]
    return dXdt

X0=torch.from_numpy(np.array([[x0, y0]])).float()
# t=np.linspace(0, tf, N_t)

# soln_arr=scipy.integrate.odeint(pred_prey_deriv, X0, t, args=(alpha, beta, delta, gamma))

# %%
# model = efficientkan.KAN(layers_hidden=[2,10,2], grid_size=5) #k is order of piecewise polynomial

# %% [markdown]
# loading the original paper

# %%
import pickle
with open('originalPaper_model@Iter10000_20260621','rb') as handle:
    model_originalPaper = pickle.load(handle)
model_originalPaper
# Out:
# KAN(
#   (layers): ModuleList(
#     (0-1): 2 x KANLinear(
#       (base_activation): SiLU()
#     )
#   )
# )

# %%
for name, param in model_originalPaper.named_parameters():
    print(f"Layer: {name} | Shape: {param.shape} | Trainable: {param.requires_grad}")
# Out:
# Layer: layers.0.base_weight | Shape: torch.Size([10, 2]) | Trainable: True
# Layer: layers.0.spline_weight | Shape: torch.Size([10, 2, 8]) | Trainable: True
# Layer: layers.0.spline_scaler | Shape: torch.Size([10, 2]) | Trainable: True
# Layer: layers.1.base_weight | Shape: torch.Size([2, 10]) | Trainable: True
# Layer: layers.1.spline_weight | Shape: torch.Size([2, 10, 8]) | Trainable: True
# Layer: layers.1.spline_scaler | Shape: torch.Size([2, 10]) | Trainable: True

# %%
# #convery numpy training data to torch tensors: 
# X0=torch.unsqueeze((torch.Tensor(np.transpose(X0))), 0)
# X0.requires_grad=True
# soln_arr=torch.Tensor(soln_arr)
# soln_arr.requires_grad=True
# soln_arr_train=soln_arr[:N_t_train, :]
# t=torch.Tensor(t)
# t_learn=torch.tensor(np.linspace(0, tf_learn, N_t_train))

def calDeriv(t, X):
    dXdt=model_originalPaper(X)
    return dXdt

# %% [markdown]
# Arithmetic Paper

# %%
# ----------------------------
# Neural ODE wrapper model
# ----------------------------
class NeuralODE(nn.Module):
    def __init__(self, func):
        super().__init__()
        self.func = func

    def forward(self, y0, t):
        # integrates from t[0] to t[-1]
        out = odeint(self.func, y0, t, method='rk4')
        # shape: [time, batch, 2]
        return out

# %%
# load 
from stable_nalu.layer.re_regualized_linear_nac import ReRegualizedLinearNACLayer
from stable_nalu.layer.re_regualized_linear_nalu import ReRegualizedLinearNALULayer

###################################################
kwargs_nalu={'eps': 1e-07,'nac_oob': 'clip','regualizer_shape': 'linear','regualizer_z': 0,'mnac_epsilon': 0,'nalu_bias': False,'nalu_two_nac': True,'nalu_two_gate': False,'nalu_mul': 'mnac','nalu_gate': 'normal'}
kwargs_nac={'eps': 1e-07,'nac_oob': 'clip','regualizer_shape': 'linear','regualizer_z': 0,'mnac_epsilon': 0,'nalu_bias': False,'nalu_two_nac': False,'nalu_two_gate': False,'nalu_mul': 'normal','nalu_gate': 'normal'}

class MyModel(nn.Module):
    def __init__(self, in_feats,h_feats, out_feat):
        super(MyModel, self).__init__()
        self.net0=nn.Linear(in_feats , h_feats*3,bias=False)
        self.net1=nn.Linear(h_feats*3 , h_feats,bias=False)
        # # self.net1_1=nn.Linear(h_feats*2 , h_feats*2,bias=False)
        self.leaKyrelu=torch.nn.LeakyReLU(0.1)
        self.net_nac=ReRegualizedLinearNACLayer(in_features=h_feats,out_features=h_feats,**kwargs_nac)
        self.net_nalu=ReRegualizedLinearNALULayer(in_features=h_feats,out_features=out_feat,**kwargs_nalu)
    def forward(self,t,inputs_):
        # h=inputs_.float()
        inputs_ = inputs_.reshape(1,-1)
        h=self.net0(inputs_.float())
        h=self.leaKyrelu(h)
        # # h=self.net1_1(h)
        # # h=self.leaKyrelu(h)
        h=self.net1(h)
        h=self.leaKyrelu(h)
        # h=self.net_nac(h)
        h=self.net_nalu(h)
        return h.double()
    def reset_parameters(self):
        torch.nn.init.xavier_uniform(self.net0.weight)
        torch.nn.init.xavier_uniform(self.net1.weight)
        # # torch.nn.init.xavier_uniform(self.net1_1.weight)
        self.net_nalu.reset_parameters()
        # self.net_nac.reset_parameters()
    def regualizer(self):
        self.net_nalu.regualizer()
        self.net_nac.regualizer()

###################################################
net = MyModel(2,2,2).to(device)
model_arithmeticPaper = NeuralODE(net).to(device)
model_arithmeticPaper.load_state_dict(torch.load('ARNN_model_weights_4972.pt'))
# Out:
# <All keys matched successfully>

# %%
import holoviews as hv
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# duration
delta_t = 0.100719#np.linspace(0, 14, 140)[1]
t=torch.tensor(np.arange(0,71,delta_t))#

# observe data
Observe = torch.from_numpy(scipy.integrate.odeint(pred_prey_deriv, X0.detach().numpy()[0], t, args=(alpha, beta, delta, gamma)))

t[:10]
# Out:
# tensor([0.0000, 0.1007, 0.2014, 0.3022, 0.4029, 0.5036, 0.6043, 0.7050, 0.8058,
#         0.9065], dtype=torch.float64)

# %%
# 
pred_originalPaper = torchodeint(calDeriv, X0, t)

pred_arithmeticPaper = model_arithmeticPaper(X0,t)

pred_originalPaper.shape,pred_arithmeticPaper.shape
# Out:
# (torch.Size([705, 1, 2]), torch.Size([705, 1, 2]))

# %%
fig = hv.Curve(pred_originalPaper.detach().numpy()[:,0,0],label='KAN-ODE').opts(color="red",line_dash="dashed",line_width=1)* \
    hv.Curve(pred_arithmeticPaper.detach().numpy()[:,0,0],label='Proposed ARNN').opts(color="blue",line_dash="dotted",line_width=3.5) *\
        hv.Curve(Observe.detach().numpy()[:,0],label='Reference').opts(color='black',line_width=1) *\
        hv.VLine(round(3.5/delta_t)).opts(color='black',line_width=1) * hv.VLine(round(14/delta_t)).opts(color='black',line_width=1)
fig.opts(width=1000,height=600,legend_cols=3,legend_position='top_left', xlabel = 'Time(s)', ylabel='Prey population', fontsize={"title":14,"labels":14,"xticks":13,"yticks":13,"legend":13},
         xticks=[35,140,200,300,400,500,600,700],ylim=(0.3,8))
        #  [(round(3.5/delta_t), '3.5'), (round(14/delta_t), '14'), (round(20/delta_t), '20'), (round(30/delta_t), '30'), (round(40/delta_t), '40'), (round(50/delta_t), '50'), (round(60/delta_t), '60'),(round(70/delta_t), '70')])#[0,100,200,300,400,500])
# Out:
# :Overlay
#    .Curve.KAN_hyphen_minus_ODE :Curve   [x]   (y)
#    .Curve.Proposed_ARNN        :Curve   [x]   (y)
#    .Curve.Reference            :Curve   [x]   (y)
#    .VLine.I                    :VLine   [x,y]
#    .VLine.II                   :VLine   [x,y]

# %%
hv.save(fig,'Prey.html')

# %%
fig = hv.Curve(pred_originalPaper.detach().numpy()[:,0,1],label='KAN-ODE').opts(color="red",line_dash="dashed",line_width=1)* \
    hv.Curve(pred_arithmeticPaper.detach().numpy()[:,0,1],label='Proposed ARNN').opts(color="blue",line_dash="dotted",line_width=3.5) *\
        hv.Curve(Observe.detach().numpy()[:,1],label='Reference').opts(color='black',line_width=1) *\
        hv.VLine(round(3.5/delta_t)).opts(color='black',line_width=1) * hv.VLine(round(14/delta_t)).opts(color='black',line_width=1)
fig.opts(width=1000,height=600,legend_cols=3,legend_position='top_left', xlabel = 'Time(s)', ylabel='Predator population', fontsize={"title":14,"labels":14,"xticks":13,"yticks":13,"legend":13},
        xticks=[35,140,200,300,400,500,600,700],ylim=(-0.9,5.2))
        #  xticks=[(round(3.5/delta_t), '3.5s'), (round(14/delta_t), '14s'), (round(20/delta_t), '20s'), (round(30/delta_t), '30s'), (round(40/delta_t), '40s'), (round(50/delta_t), '50s'), (round(60/delta_t), '60s'),(round(70/delta_t), '70s')])#[0,100,200,300,400,500])
# Out:
# :Overlay
#    .Curve.KAN_hyphen_minus_ODE :Curve   [x]   (y)
#    .Curve.Proposed_ARNN        :Curve   [x]   (y)
#    .Curve.Reference            :Curve   [x]   (y)
#    .VLine.I                    :VLine   [x,y]
#    .VLine.II                   :VLine   [x,y]

# %%
hv.save(fig,'predator_population.html')

# %%
# fig = hv.Curve(pred_originalPaper.detach().numpy()[:,0,1],label='Original paper').opts(color='red')* \
#     hv.Curve(pred_arithmeticPaper.detach().numpy()[:,0,1],label='Arithmetic paper').opts(color='blue') \
#         *hv.Curve(Observe.detach().numpy()[:,1],label='Observe').opts(color='green')
# fig.opts(width=800,height=600,legend_cols=3,legend_position='top_left')

# %%
# Out:
# (35, 1, 2)

# %%
import holoviews as hv
from holoviews import dim
import pandas as pd
import numpy as np
import random

# %%
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
df = pd.read_excel("./ARNN_performance.xlsx","Loss")

# %%
fig = hv.Scatter(df,kdims=['Epoch'],vdims=['Training'],label='Training').opts(marker='s')*hv.Scatter(df,kdims=['Epoch'],vdims=['Validation'],label='Validation') \
.opts(width=600, height=400, logy=True, ylabel = 'Loss (MSE)', fontsize={"title": 10,"labels": 12,"ticks": 12,"legend": 12})

# %%
fig = fig*hv.Text(7800,0.015,'2.4e-2')*hv.Text(7800,0.1,'3.5-2')
# 0.02422078	0.035035405

# %%
hv.save(fig,"ARNN_performance.html")
